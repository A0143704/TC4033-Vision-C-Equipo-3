# %% [markdown]
# <a href="https://colab.research.google.com/github/A0143704/TC4033-Vision-C-Equipo-3/blob/main/10_morphological_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![tec.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Visión computacional para imágenes y video (Gpo 10)**
# ###Tecnológico de Monterrey
# ### **Prof Dr. Gilberto Ochoa Ruiz**
# ### *4.2 Google Colab - Algoritmos de mejoramiento de imágenes usando operaciones morfológicas*
#
# <center>
#
# |   |   |
# |---|---|
# | Matrícula | Alumno|
# | A01793474   | Juan Pablo Bladinieres Martin del Campo|
# | A01793546  | José Ariel Corral|
# | A01794050  | José Bernardo Moreno Villarreal|
# | A01021190   | Ian André Ortega Suárez|
# | A00143704   | Moisés Rangel Silva  |
#
# </center>

# %% [markdown]
# # 10. Morphological Operations
#
# ## Table of Contents
# 1. Importing Libraries
# 2. A) Investigar una aplicación de erosión en procesamiento de imágenes e implementarlo en Colab)
# 3. B) Investigar una aplicación de dilatación en procesamiento de imágenes e implementarlo en Colab)
# 4. C) Investigar una aplicación de opening y closing e implementalo en Google Colab
# 5. Realizando una comparación entre cada uno de los procesos
# 6. Incluyendo los procesos de procesamiento de imagen morfológicos de Top Hat & Black Hat
# 7. Conclusiones
# 8. Referencias

# %% [markdown]
# ## 1. Importing Libraries <a class="anchor" id="libraries" ></a>

# %%
import cv2
import sys
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from IPython.utils.py3compat import iteritems

# %% [markdown]
# ##Preguntas:

# %% [markdown]
# Para este ejercicio usaremos una imagen del proceso de inspección de soldadura con Rayos X en un Semiconductor:

# %% [markdown]
# ![chip1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ###2. A) Investigar una aplicación de erosión en procesamiento de imágenes e implementarlo en Colab

# %%
img = cv2.imread('/content/data/chip1.jpg', cv2.IMREAD_GRAYSCALE)
_, mask = cv2.threshold(img,220,255, cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2), np.uint8)

erosion = cv2.erode(mask, kernal, iterations =2)

titulos = ['Original','Binary Threshold','Erosion']
imagenes = [img,mask,erosion]

for i in range (3):
  plt.subplot (1,3,i+1),plt.imshow(imagenes[i], 'gray')
  plt.title(titulos[i])
  plt.xticks([]),plt.yticks([])

plt.show()

# %% [markdown]
# * *Este proceso nos permite acentuar ciertos bordes y hacerlos mucho mas facil de identificar, incluso reforzándolos y entre más iteraciones empleemos, se acentuará más*

# %% [markdown]
# ###3. B) Investigar una aplicación de dilatación en procesamiento de imágenes e implementarlo en Colab

# %%
img = cv2.imread('/content/data/chip1.jpg', cv2.IMREAD_GRAYSCALE)
_, mask = cv2.threshold(img,220,255, cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2), np.uint8)

dilatacion = cv2.dilate(mask,kernal, iterations=3)

titulos = ['Original','Binary Threshold','Dilatacion']
imagenes = [img,mask,dilatacion]

for i in range (3):
  plt.subplot (1,3,i+1),plt.imshow(imagenes[i], 'gray')
  plt.title(titulos[i])
  plt.xticks([]),plt.yticks([])

plt.show()

# %% [markdown]
# * *Este proceso, se podría describir como para ampliar los bordes y haciéndolos mucho més claros a simple vista, para este ejemplo podemos ver como solo ciertos puntos de los bordes de soldadura están "fríos", que son los que presentan una burbuja.*

# %% [markdown]
# ###4. C) Investigar una aplicación de opening y closing e implementalo en Google Colab

# %%
img = cv2.imread('/content/data/chip1.jpg', cv2.IMREAD_GRAYSCALE)
_, mask = cv2.threshold(img,220,255, cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2), np.uint8)

opening = cv2.morphologyEx(mask,cv2.MORPH_OPEN, kernal)
closing = cv2.morphologyEx(mask,cv2.MORPH_CLOSE, kernal)

titulos = ['Original','Binary Threshold','Opening','Closing']
imagenes = [img,mask,opening, closing]

for i in range (4):
  plt.subplot (2,2,i+1),plt.imshow(imagenes[i], 'gray')
  plt.title(titulos[i])
  plt.xticks([]),plt.yticks([])

plt.show()

# %% [markdown]
# * *Entre el opening y el closing, se estan llevando a cabo el reforzamiendo de los bordes que son muy semejantes al proceso de dilatación y erosion, pero que se encargan de los bordes más suavizados*

# %% [markdown]
# ###5. Realizando una comparación entre cada uno de los procesos:

# %%
img = cv2.imread('/content/data/chip1.jpg', cv2.IMREAD_GRAYSCALE)
_, mask = cv2.threshold(img,220,255, cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2), np.uint8)
erosion = cv2.erode(mask, kernal, iterations =2)
dilatacion = cv2.dilate(mask,kernal, iterations=3)
opening = cv2.morphologyEx(mask,cv2.MORPH_OPEN, kernal)
closing = cv2.morphologyEx(mask,cv2.MORPH_CLOSE, kernal)

titulos = ['Original','Binary Threshold','Erosion','Dilatación','Opening','Closing']
imagenes = [img,mask,erosion,dilatacion,opening,closing]

for i in range (6):
  plt.subplot (2,3,i+1),plt.imshow(imagenes[i], 'gray')
  plt.title(titulos[i])
  plt.xticks([]),plt.yticks([])

plt.show()

# %% [markdown]
# ### 6. Incluyendo los procesos de procesamiento de imagen morfológicos de Top Hat & Black Hat:

# %%
img = cv2.imread('/content/data/chip1.jpg', cv2.IMREAD_GRAYSCALE)
_, mask = cv2.threshold(img,220,255, cv2.THRESH_BINARY_INV)

kernal = np.ones((2,2), np.uint8)

erosion = cv2.erode(mask, kernal, iterations =2)
dilatacion = cv2.dilate(mask,kernal, iterations=3)
opening = cv2.morphologyEx(mask,cv2.MORPH_OPEN, kernal)
closing = cv2.morphologyEx(mask,cv2.MORPH_CLOSE, kernal)
tophat = cv2.morphologyEx(mask, cv2.MORPH_TOPHAT, kernal)
blackhat = cv2.morphologyEx(mask,cv2.MORPH_BLACKHAT,kernal)

titulos = ['Original','Binary Threshold','Erosion','Dilatación','Opening','Closing','Tophat','Blackhat']
imagenes = [img,mask,erosion,dilatacion,opening,closing,tophat,blackhat]

for i in range (8):
  plt.subplot (2,4,i+1),plt.imshow(imagenes[i], 'gray')
  plt.title(titulos[i])
  plt.xticks([]),plt.yticks([])

plt.show()

# %% [markdown]
# ## 7. Conclusiones:
#
# * *Como conclusiones, para este caso que se analiza, podemos identificar que el procesamiento de imágenes puede ayudarnos en la automatizaciones de procesos para descartar o confirmar la calidad de un producto, así mismo, se puede observar que el comportamiento de cada procesamiento de las imágenes, nos permite identificar patrones que para el área médico, por ejm,plo, que daría una herramienta  a los medicos para optimizar los diagnósticos observando las diferencias en las imágenes.*
#
# * *Pueden ser variados los procesos de imághenes y para hacerlo mucho más sencillo de interpretar, consideramos que el poder tener un proceso donde llevamos acabo una comparación u observación de un patron visual, podemos realizar la optimización de procesos de imagenes y apoyar en la toma de decisiones.*
#
# * *Incluso durante el proceso de investigación, pude haber ciertos casos donde se pueden usar para el procesamiento de escritura y con ello poder hacer mucho mejor la interpretación de los caracteres, por ejemplo.*

# %% [markdown]
# Imagen Real

# %% [markdown]
# ![Vectra-xa-graphiccard_hg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Rayos X

# %% [markdown]
# ![Vectra-xa-graphiccard-xray_hg.jpg](data:image/jpeg;base64,...)

# %%
#@title Default title text { run: "auto" }
# print("Imagen Binary Threshold")
img = cv2.imread('/content/data/Vectra-xa-graphiccard-xray_hg.jpg', cv2.IMREAD_GRAYSCALE)
_, mask = cv2.threshold(img,100,255, cv2.THRESH_BINARY_INV)

titulos = ['Binary Threshold']
imagenes = [mask]

for i in range (1):
  plt.subplot (1,1,i+1),plt.imshow(imagenes[i], 'gray')
  plt.title(titulos[i])
  plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# ##8. Referencias:
# * *OpenCV Morphological Operations. (2021, April 28). PyImageSearch. https://pyimagesearch.com/2021/04/28/opencv-morphological-operations/*
#
#
# * *OpenCV: Morphological Transformations. (n.d.). Docs.opencv.org. https://docs.opencv.org/4.x/d9/d61/tutorial_py_morphological_ops.html*
#
# * *Chhikara, P. (2022, April 3). Understanding Morphological Image Processing and Its Operations. Medium. https://towardsdatascience.com/understanding-morphological-image-processing-and-its-operations-7bcf1ed11756*
#
# * *Singh, R. (2020, November 5). Morphological Transformations of Images using OpenCV | Image Processing Part-2. Analytics Vidhya. https://medium.com/analytics-vidhya/morphological-transformations-of-images-using-opencv-image-processing-part-2-f64b14af2a38*
#
# * *Grobe, H. (2020, November 22). English: Circuit board, graphic card. Wikimedia Commons. https://commons.wikimedia.org/wiki/File:Vectra-xa-graphiccard-xray_hg.jpg#/media/File:Vectra-xa-graphiccard_hg.jpg*
#
# * *X Line Series. (n.d.). Www.goepel.com. Retrieved February 3, 2023, from https://www.goepel.com/en/inspection-solutions/axi/x-ray-inspection-systems/x-line-series.html*
#
# * Gonzalez, R. & Woods, R. (2018). Digital Image Processing.  4° Edition. Pearson.
# * **
# * **
# * **
